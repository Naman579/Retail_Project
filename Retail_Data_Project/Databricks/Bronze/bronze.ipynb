# %%
# %run /Workspace/Users/nk1956663@gmail.com/Functions

# %%
connect()

# %%
# Orders.csv path 

path_Orders="abfss://test@projstorageaccount.dfs.core.windows.net/Retail_data/Landing/Bronze/dbo.Orders.csv"

# %%
# Read Order.csv

Orders = rcsv(path_Orders)
display(Orders)

# %%
# Saving File in Bronze Layer


# Bronze path
bronze_path = "/Volumes/proj_databricks/retail/bronze/Orders"


Orders.write \
.format("delta") \
.mode("append") \
.save(bronze_path)

# %%
# Products.parquet path

path_Products="abfss://test@projstorageaccount.dfs.core.windows.net/Retail_data/Landing/Bronze/Products.parquet"

# %%
# Read Prodcuts.parquet

Products = rpar(path_Products)
display(Products)

# %%
# Saving File in Bronze Layer


# Bronze path
bronze_path = "/Volumes/proj_databricks/retail/bronze/Products"


Products.write \
.format("delta") \
.mode("append") \
.save(bronze_path)

# %%
# Customer.json path

path_Customers="abfss://test@projstorageaccount.dfs.core.windows.net/Retail_data/Landing/Bronze/Customers.json"

# %%
# Read Customer.json

Customers = rjson(path_Customers)
display(Customers)

# %%
# Saving File in Bronze Layer


# Bronze path
bronze_path = "/Volumes/proj_databricks/retail/bronze/Customers"


Customers.write \
.format("delta") \
.mode("append") \
.save(bronze_path)
